# %%
import geopandas as gpd

# Cargar el archivo GeoJSON
# Se recomienda usar barras inclinadas hacia adelante (/) para la compatibilidad entre sistemas operativos.
ruta_archivo = "datos/departamentos/Colombia.geo.json"
departamentos = gpd.read_file(ruta_archivo)
# Visualizar el mapa de los departamentos
departamentos.plot(figsize=(10, 10), edgecolor="black")
# Out:
# <Axes: >

# %%
import pandas as pd
datos = pd.read_excel("datos/proyectos/proyecto_colombia.xlsx")
datos.head()
# Out:
#                                  Nombre del Artículo Departamento  \
# 0  Viabilidad técnica para la creación de un comp...        HUILA
# 1  Study of Wind Potential on the La Bella Farm i...        HUILA
# 2  Metodología para la determinación de caracterí...      NARIÑO
# 3  Impacto de la generación eléctrica con fuentes...      NARIÑO
# 4  Identificación de proyectos con potencial de g...      BOYACÁ
#
#                           Municipio     Latitud         Longitud  \
# 0           Colombia ("La Legiosa")  3.39127 ∘ N  (-74.78279° O)
# 1          Acevedo (Finca La Bella)    1.8047° N   (-75.8928° O)
# 2  Túquerres (Sabana de Túquerres)     1.0875° N   (-77.6189° O)
# 3          Pasto (UCC Campus Pasto)    1.2059° N   (-77.2850° O)
# 4        Samacá, Duitama, Aquitania   5.4928° N   (-73.4867° O)
#
#                     Aerogenerador / modelo propuesto  \
# 0                                 Gamesa G97 de 2 MW
# 1            No aplica (sistema de microgeneración)
# ...

# %%
# Muestra las columnas del GeoDataFrame
departamentos.columns
# Out:
# Index(['DPTO', 'NOMBRE_DPT', 'AREA', 'PERIMETER', 'HECTARES', 'geometry'], dtype='object')

# %%
print(departamentos['NOMBRE_DPT'].unique())
# Out:
# ['ANTIOQUIA' 'ATLANTICO' 'SANTAFE DE BOGOTA D.C' 'BOLIVAR' 'BOYACA'
#  'CALDAS' 'CAQUETA' 'CAUCA' 'CESAR' 'CORDOBA' 'CUNDINAMARCA' 'CHOCO'
#  'HUILA' 'LA GUAJIRA' 'MAGDALENA' 'META' 'NARIÑO' 'NORTE DE SANTANDER'
#  'QUINDIO' 'RISARALDA' 'SANTANDER' 'SUCRE' 'TOLIMA' 'VALLE DEL CAUCA'
#  'ARAUCA' 'CASANARE' 'PUTUMAYO' 'AMAZONAS' 'GUAINIA' 'GUAVIARE' 'VAUPES'
#  'VICHADA' 'ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA']
